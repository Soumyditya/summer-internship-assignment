# %%
import pandas as pd

# Load dataset
data = pd.read_csv("/content/digital_burnout_productivity_dataset_5M (1).csv")


# Handle Missing Values


# Fill numerical missing values with mean
numeric_columns = data.select_dtypes(include=["int64", "float64"]).columns

for col in numeric_columns:
    data[col].fillna(data[col].mean(), inplace=True)

# Fill categorical missing values with mode
categorical_columns = data.select_dtypes(include=["object"]).columns

for col in categorical_columns:
    data[col].fillna(data[col].mode()[0], inplace=True)

# Remove Duplicate Rows


data = data.drop_duplicates()


# Show Dataset Statistics


print("\nDataset Information:\n")
print(data.info())

print("\nDataset Statistics:\n")
print(data.describe())


# Encode Categorical Columns


# Convert categorical columns into numeric values
for col in categorical_columns:

    data[col] = data[col].astype("category").cat.codes

# Save Cleaned Dataset


data.to_csv("cleaned_dataset.csv", index=False)

print("\nCleaned dataset saved successfully!")
# Out:
# /tmp/ipykernel_681/1972839011.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mean(), inplace=True)
# /tmp/ipykernel_681/1972839011.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mode()[0], inplace=True)
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596118 entries, 0 to 596117
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   user_id                  596118 non-null  int64
#  1   age                      596118 non-null  int64
#  2   occupation               596118 non-null  object
#  3   work_mode                596118 non-null  object
#  4   device_usage_type        596118 non-null  object
#  5   daily_screen_time        596118 non-null  float64
#  6   social_media_hours       596118 non-null  float64
#  7   doomscrolling_duration   596118 non-null  float64
#  8   app_switch_frequency     596118 non-null  int64
#  9   notification_count       596118 non-null  int64
#  10  smartphone_unlocks       596118 non-null  int64
#  11  late_night_device_usage  596118 non-null  int64
#  12  focus_sessions           596118 non-null  int64
#  13  deep_work_hours          596118 non-null  float64
#  14  distraction_frequency    596118 non-null  int64
#  15  task_completion_rate     596118 non-null  int64
#  16  concentration_score      596118 non-null  float64
#  17  sleep_hours              596118 non-null  float64
#  18  sleep_quality            596118 non-null  float64
#  19  caffeine_intake          596118 non-null  float64
#  20  physical_activity        596118 non-null  float64
#  21  stress_level             596118 non-null  float64
#  22  workspace_quality        596118 non-null  float64
#  23  meeting_hours            596118 non-null  float64
#  24  internet_stability       596118 non-null  float64
#  25  remote_work_days         596118 non-null  float64
#  26  motivation_level         596118 non-null  float64
#  27  mental_fatigue           596118 non-null  float64
#  28  emotional_exhaustion     596118 non-null  float64
#  29  work_satisfaction        596118 non-null  float64
#  30  mental_state             596118 non-null  object
#  31  burnout_risk             596118 non-null  float64
#  32  productivity_score       596118 non-null  float64
#  33  productivity_category    596118 non-null  object
# dtypes: float64(20), int64(9), object(5)
# memory usage: 154.6+ MB
# None
#
# Dataset Statistics:
#
#              user_id            age  daily_screen_time  social_media_hours  \
# count  596118.000000  596118.000000      596118.000000       596118.000000
# mean   298059.500000      38.523896           8.000311            3.516629
# std    172084.588221      12.119687           2.498786            1.745379
# min         1.000000      18.000000           1.000000            0.000000
# 25%    149030.250000      28.000000           6.300000            2.300000
# 50%    298059.500000      39.000000           8.000000            3.500000
# 75%    447088.750000      49.000000           9.700000            4.700000
# max    596118.000000      59.000000          18.000000           12.000000
#
#        doomscrolling_duration  app_switch_frequency  notification_count  \
# count           596118.000000         596118.000000       596118.000000
# mean                 1.834085            129.670246          209.360573
# std                  1.132834             69.275070          109.592900
# min                  0.000000             10.000000           20.000000
# 25%                  1.000000             70.000000          115.000000
# 50%                  1.800000            130.000000          209.000000
# 75%                  2.600000            190.000000          304.000000
# max                  7.800000            249.000000          399.000000
#
#        smartphone_unlocks  late_night_device_usage  focus_sessions  ...  \
# count       596118.000000            596118.000000   596118.000000  ...
# mean           157.075764                 0.650507        4.502830  ...
# std             82.274950                 0.476810        2.873249  ...
# min             15.000000                 0.000000        0.000000  ...
# 25%             86.000000                 0.000000        2.000000  ...
# 50%            157.000000                 1.000000        5.000000  ...
# 75%            228.000000                 1.000000        7.000000  ...
# max            299.000000                 1.000000        9.000000  ...
#
#        workspace_quality  meeting_hours  internet_stability  remote_work_days  \
# count      596118.000000  596118.000000       596118.000000     596118.000000
# mean            5.499521       2.532565            5.502735          3.000683
# std             2.871466       1.438100            2.874114          1.997606
# min             1.000000       0.000000            1.000000          0.000000
# 25%             3.000000       1.500000            3.000000          1.000000
# 50%             5.000000       2.500000            6.000000          3.000000
# 75%             8.000000       3.500000            8.000000          5.000000
# max            10.000000      10.000000           10.000000          6.000000
#
#        motivation_level  mental_fatigue  emotional_exhaustion  \
# count     596118.000000   596118.000000         596118.000000
# mean           5.498547        5.498062              5.502289
# std            2.843491        2.870417              2.871991
# min            1.000000        1.000000              1.000000
# 25%            3.000000        3.000000              3.000000
# 50%            5.498547        5.000000              6.000000
# 75%            8.000000        8.000000              8.000000
# max           10.000000       10.000000             10.000000
#
#        work_satisfaction   burnout_risk  productivity_score
# count      596118.000000  596118.000000       596118.000000
# mean            5.501459      48.604717           71.436807
# std             2.872561      22.116377           21.490882
# min             1.000000       0.000000            0.000000
# 25%             3.000000      33.000000           56.000000
# 50%             5.000000      49.000000           73.000000
# 75%             8.000000      64.000000           90.000000
# max            10.000000     100.000000          100.000000
#
# [8 rows x 29 columns]
#
# Cleaned dataset saved successfully!
