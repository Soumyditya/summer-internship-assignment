# %%
"""
Error code

numbers = [1, 2, 3, 4, 5]
for i in range(len(numbers)):
numbers.remove(numbers[i])
print(numbers)

The bug occurs because the list is being modified while iterating through it.
When an element is removed, the remaining elements shift to the left, but the loop
counter continues to increase, causing some elements to be skipped and sometimes leading to an IndexError.
A correct solution is to use numbers.clear() or remove elements without iterating over changing indexes.
The time complexity of the corrected approach is O(n) because each element is removed once.

"""
# Correct Code

numbers = [1, 2, 3, 4, 5]

while numbers:
    numbers.pop()

print(numbers)
